# %% [markdown]
# **Things to extract**
# - Utility Name
# - Issued Date
#
# - Company Name
# - Street
# - City
# - State
# - Zip
#
# - Electric Choice ID#
# - Rate Code
# - Usage
# - Supplier

# %%
import pdfplumber
import pandas as pd

# %%
with pdfplumber.open("PII Example 1.pdf") as pdf:
    for page in pdf.pages:
        first_page = pdf.pages[0]
#     second_page = pdf.pages[1]

# %%
#extracting info from the address on the first page

#coordinates of the second top quarter of the page
top_half_p1 = first_page.height/2
top_quarter_p1 = first_page.height/4
second_quarter_p1 = top_half_p1 - top_quarter_p1

#coordinates of the address box
address_box_left = (first_page.width//2) - 20
address_box_top = second_quarter_p1 - 75
address_box_right = first_page.width
address_box_bottom = (first_page.height//2) -215

print(address_box_left,address_box_top,address_box_right,address_box_bottom)
# Out:
# 286 123 612 181

# %%
# bounding_box expressed as (x0, top, x1, bottom)
## address_bounding_box = ((first_page.width//2) - 20, second_quarter_p1 - 75, first_page.width, (first_page.height//2) -215)
address_bounding_box = (address_box_left,address_box_top,address_box_right,address_box_bottom)
first_page.to_image()

# %%
address_box = first_page.crop(address_bounding_box)
address_box.to_image()

# %%
# address_extract = first_page.crop(address_bounding_box).extract_text(x_tolerance=1)
address_extract  = address_box.extract_text(x_tolerance = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b1f88a7eaf48> in <module>
#       1 # address_extract = first_page.crop(address_bounding_box).extract_text(x_tolerance=1)
# ----> 2 address_extract  = address_box.extract_text(x_tolerance = 1)
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/page.py in extract_text(self, **kwargs)
#     267
#     268     def extract_text(self, **kwargs):
# --> 269         return utils.extract_text(self.chars, **kwargs)
#     270
#     271     def extract_words(self, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/container.py in chars(self)
#      46     @property
#      47     def chars(self):
# ---> 48         return self.objects.get("char", [])
#      49
#      50     @property
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/page.py in objects(self)
#     365         if hasattr(self, "_objects"):
#     366             return self._objects
# --> 367         self._objects = self.crop_fn(self.parent_page.objects, self.bbox)
#     368         return self._objects
#     369
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/page.py in objects(self)
#     159         if hasattr(self, "_objects"):
#     160             return self._objects
# --> 161         self._objects = self.parse_objects()
#     162         return self._objects
#     163
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/page.py in parse_objects(self)
#     220     def parse_objects(self):
#     221         objects = {}
# --> 222         for obj in self.iter_layout_objects(self.layout._objs):
#     223             kind = obj["object_type"]
#     224             if kind in ["anno"]:
#
# ~/.local/lib/python3.6/site-packages/pdfplumber/page.py in layout(self)
#     108         )
#     109         interpreter = PDFPageInterpreter(self.pdf.rsrcmgr, device)
# --> 110         interpreter.process_page(self.page_obj)
#     111         self._layout = device.get_result()
#     112         return self._layout
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdfinterp.py in process_page(self, page)
#     893             ctm = (1, 0, 0, 1, -x0, -y0)
#     894         self.device.begin_page(page, ctm)
# --> 895         self.render_contents(page.resources, page.contents, ctm=ctm)
#     896         self.device.end_page(page)
#     897         return
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdfinterp.py in render_contents(self, resources, streams, ctm)
#     904         log.info('render_contents: resources=%r, streams=%r, ctm=%r',
#     905                  resources, streams, ctm)
# --> 906         self.init_resources(resources)
#     907         self.init_state(ctm)
#     908         self.execute(list_value(streams))
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdfinterp.py in init_resources(self, resources)
#     351                     if isinstance(spec, PDFObjRef):
#     352                         objid = spec.objid
# --> 353                     spec = dict_value(spec)
#     354                     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#     355             elif k == 'ColorSpace':
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdftypes.py in dict_value(x)
#     168
#     169 def dict_value(x):
# --> 170     x = resolve1(x)
#     171     if not isinstance(x, dict):
#     172         if settings.STRICT:
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdftypes.py in resolve1(x, default)
#      80     """
#      81     while isinstance(x, PDFObjRef):
# ---> 82         x = x.resolve(default=default)
#      83     return x
#      84
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdftypes.py in resolve(self, default)
#      68     def resolve(self, default=None):
#      69         try:
# ---> 70             return self.doc.getobj(self.objid)
#      71         except PDFObjectNotFound:
#      72             return default
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdfdocument.py in getobj(self, objid)
#     681                         obj = self._getobj_objstm(stream, index, objid)
#     682                     else:
# --> 683                         obj = self._getobj_parse(index, objid)
#     684                         if self.decipher:
#     685                             obj = decipher_all(self.decipher, objid, genno,
#
# ~/.local/lib/python3.6/site-packages/pdfminer/pdfdocument.py in _getobj_parse(self, pos, objid)
#     632
#     633     def _getobj_parse(self, pos, objid):
# --> 634         self._parser.seek(pos)
#     635         (_, objid1) = self._parser.nexttoken()  # objid
#     636         (_, genno) = self._parser.nexttoken()  # genno
#
# ~/.local/lib/python3.6/site-packages/pdfminer/psparser.py in seek(self, pos)
#     512
#     513     def seek(self, pos):
# --> 514         PSBaseParser.seek(self, pos)
#     515         self.reset()
#     516         return
#
# ~/.local/lib/python3.6/site-packages/pdfminer/psparser.py in seek(self, pos)
#     200         """
#     201         log.debug('seek: %r', pos)
# --> 202         self.fp.seek(pos)
#     203         # reset the status for nextline()
#     204         self.bufpos = pos
#
# ValueError: seek of closed file

# %%
company_name = address_extract.splitlines()[0]
company_name

# %%
street = address_extract.splitlines()[1]
street

# %%
city_state_zip = address_extract.splitlines()[2]
city_state_zip = city_state_zip.replace(',', '')

city = city_state_zip.split(' ')[0]
state =  city_state_zip.split(' ')[1]
zip_code =  city_state_zip.split(' ')[2]
print(city, state, zip_code)

# %%
account_number = address_extract
